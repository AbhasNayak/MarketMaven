# %% [markdown]
# ##  1.. Data Collection !

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob

# %%
glob.glob(r'D:\S&P_resources\individual_stocks_5yr/*csv')
# Out:
# ['D:\\S&P_resources\\individual_stocks_5yr\\AAL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AAPL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AAP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ABBV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ABC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ABT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ACN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ADBE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ADI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ADM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ADP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ADSK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ADS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AEE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AEP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AES_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AET_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AFL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AGN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AIG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AIV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AIZ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AJG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AKAM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ALB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ALGN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ALK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ALLE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ALL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ALXN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMAT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AME_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMGN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AMZN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ANDV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ANSS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ANTM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AON_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AOS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\APA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\APC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\APD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\APH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\APTV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ARE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ARNC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ATVI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AVB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AVGO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AVY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AWK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AXP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AYI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\AZO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\A_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BAC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BAX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BBT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BBY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BDX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BEN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BF.B_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BHF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BHGE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BIIB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BLK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BLL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BMY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BRK.B_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BSX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BWA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\BXP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CAG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CAH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CAT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CBG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CBOE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CBS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CCI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CCL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CDNS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CELG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CERN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CFG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CHD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CHK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CHRW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CHTR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CINF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CLX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CMA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CMCSA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CME_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CMG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CMI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CMS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CNC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CNP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COST_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\COTY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CPB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CRM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CSCO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CSRA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CSX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CTAS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CTL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CTSH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CTXS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CVS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CVX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\CXO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\C_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DAL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DFS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DGX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DHI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DHR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DISCA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DISCK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DISH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DIS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DLR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DLTR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DOV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DPS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DRE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DRI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DTE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DUK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DVA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DVN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DWDP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\DXC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\D_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EBAY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ECL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ED_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EFX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EIX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EMN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EMR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EOG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EQIX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EQR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EQT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ESRX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ESS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ES_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ETFC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ETN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ETR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EVHC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EXC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EXPD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EXPE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\EXR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FAST_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FBHS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FCX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FDX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FFIV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FISV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FIS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FITB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FLIR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FLR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FLS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FMC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FOXA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FOX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FRT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FTI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\FTV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\F_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GGP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GILD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GIS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GLW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GOOGL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GOOG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GPC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GPN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GPS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GRMN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\GWW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HAL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HAS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HBAN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HBI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HCA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HCN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HCP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HES_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HIG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HII_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HLT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HOG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HOLX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HON_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HPE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HPQ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HRB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HRL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HRS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HSIC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HST_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HSY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\HUM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IBM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ICE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IDXX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IFF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ILMN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\INCY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\INFO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\INTC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\INTU_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IPG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IQV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IRM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ISRG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ITW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\IVZ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JBHT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JCI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JEC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JNJ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JNPR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JPM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\JWN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KEY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KHC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KIM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KLAC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KMB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KMI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KMX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KORS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KSS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\KSU_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\K_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LEG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LEN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LKQ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LLL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LLY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LMT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LNC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LNT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LOW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LRCX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LUK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LUV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\LYB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\L_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MAA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MAC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MAR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MAS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MAT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MCD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MCHP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MCK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MCO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MDLZ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MDT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MET_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MGM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MHK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MKC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MLM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MMC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MMM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MNST_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MON_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MOS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MPC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MRK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MRO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MSFT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MSI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MTB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MTD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MU_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\MYL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\M_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NAVI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NBL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NCLH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NDAQ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NEE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NEM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NFLX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NFX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NKE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NLSN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NOC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NOV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NRG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NSC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NTAP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NTRS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NUE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NVDA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NWL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NWSA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\NWS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\OKE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\OMC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ORCL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ORLY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\OXY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\O_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PAYX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PBCT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PCAR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PCG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PCLN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PDCO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PEG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PEP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PFE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PFG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PGR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PHM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PKG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PKI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PLD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PNC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PNR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PNW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PPG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PPL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PRGO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PRU_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PSA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PSX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PVH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PWR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PXD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\PYPL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\QCOM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\QRVO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RCL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\REGN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\REG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RHI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RHT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RJF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RMD_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ROK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ROP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ROST_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RRC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RSG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\RTN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SBAC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SBUX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SCG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SCHW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SEE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SHW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SIG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SJM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SLB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SLG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SNA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SNI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SNPS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SPGI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SPG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SRCL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SRE_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\STI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\STT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\STX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\STZ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SWKS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SWK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SYF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SYK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SYMC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\SYY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TAP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TDG_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TEL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TGT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TIF_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TJX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TMK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TMO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TPR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TRIP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TROW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TRV_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TSCO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TSN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TSS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TWX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TXN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\TXT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\T_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UAA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UAL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UDR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UHS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ULTA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UNH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UNM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UNP_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UPS_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\URI_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\USB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\UTX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VAR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VFC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VIAB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VLO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VMC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VNO_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VRSK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VRSN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VRTX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VTR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\VZ_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\V_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WAT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WBA_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WDC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WEC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WFC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WHR_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WLTW_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WMB_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WMT_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WRK_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WU_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WYNN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WYN_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\WY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XEC_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XEL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XLNX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XOM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XRAY_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XRX_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\XYL_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\YUM_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ZBH_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ZION_data.csv',
#  'D:\\S&P_resources\\individual_stocks_5yr\\ZTS_data.csv']

# %%
len(glob.glob(r'D:\S&P_resources\individual_stocks_5yr/*csv')) ## total files we have
# Out:
# 505

# %%
# lets store files of those stock that we have to consider for analysis ..

# %%
company_list = [
    r'D:\\S&P_resources\\individual_stocks_5yr\\AAPL_data.csv' , 
    r'D:\\S&P_resources\\individual_stocks_5yr\\AMZN_data.csv' , 
    r'D:\\S&P_resources\\individual_stocks_5yr\\GOOG_data.csv' , 
    r'D:\\S&P_resources\\individual_stocks_5yr\\MSFT_data.csv'
    
]

# %%
## use Warnings package to get rid of any future warning ..

import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
all_data = pd.DataFrame()

for file in company_list:
    
    current_df = pd.read_csv(file)
    
    
    all_data = pd.concat([all_data , current_df] , ignore_index=True)

# %%
all_data.shape ## dimensions of all_data dataframe ..
# Out:
# (4752, 7)

# %%
all_data.head(6)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5  2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL

# %%
all_data['Name'].unique()
# Out:
# array(['AAPL', 'AMZN', 'GOOG', 'MSFT'], dtype=object)

# %% [markdown]
# ## 2.. Analysing change in price of the stock overtime !

# %%
all_data.isnull().sum() ## checking missing values
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
all_data.dtypes ## checking data-types
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
all_data['date'] = pd.to_datetime(all_data['date']) ## converting data-type of "date" featuer into date-time ..

# %%
all_data['date']
# Out:
# 0      2013-02-08
# 1      2013-02-11
# 2      2013-02-12
# 3      2013-02-13
# 4      2013-02-14
#           ...
# 4747   2018-02-01
# 4748   2018-02-02
# 4749   2018-02-05
# 4750   2018-02-06
# 4751   2018-02-07
# Name: date, Length: 4752, dtype: datetime64[ns]

# %%
tech_list = all_data['Name'].unique()

# %%
tech_list
# Out:
# array(['AAPL', 'AMZN', 'GOOG', 'MSFT'], dtype=object)

# %%
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index) ## creating subplot for each stock
    filter1 = all_data['Name']==company
    df = all_data[filter1]
    plt.plot(df['date'] , df['close']) ## plotting "date" vs "close"
    plt.title(company)

# %% [markdown]
# ## 3.. moving average of the various stocks !

# %%
all_data.head(15)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5  2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 6  2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 7  2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 8  2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 9  2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL
# 10 2013-02-25  64.8356  65.0171  63.2242  63.2571   92899597  AAPL
# 11 2013-02-26  63.4028  64.5056  62.5228  64.1385  125096657  AAPL
# 12 2013-02-27  64.0614  64.6342  62.9499  63.5099  146674682  AAPL
# 13 2013-02-28  63.4357  63.9814  63.0571  63.0571   80532382  AAPL
# 14 2013-03-01  62.5714  62.5971  61.4257  61.4957  137899041  AAPL

# %%
all_data['close'].rolling(window=10).mean().head(14)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     66.03251
# 10    65.57280
# 11    65.13051
# 12    64.79722
# 13    64.43137
# Name: close, dtype: float64

# %%
new_data = all_data.copy()

# %%
#### now lets consider different windows of rolling ,ie 10 days ,20 days ,30 days 
ma_day = [10 ,20 , 50]

for ma in ma_day:
    new_data['close_'+str(ma)] = new_data['close'].rolling(ma).mean()

# %%
new_data.tail(7)
# Out:
#            date   open    high      low  close    volume  Name  close_10  \
# 4745 2018-01-30  93.30  93.660  92.1000  92.74  38635053  MSFT    91.862
# 4746 2018-01-31  93.75  95.400  93.5100  95.01  48756338  MSFT    92.349
# 4747 2018-02-01  94.79  96.070  93.5813  94.26  47227882  MSFT    92.765
# 4748 2018-02-02  93.64  93.970  91.5000  91.78  47867753  MSFT    92.943
# 4749 2018-02-05  90.56  93.240  88.0000  88.00  51031465  MSFT    92.582
# 4750 2018-02-06  86.89  91.475  85.2500  91.33  67998564  MSFT    92.525
# 4751 2018-02-07  90.49  91.770  89.2000  89.61  41107592  MSFT    92.304
#
#       close_20  close_50
# 4745   89.8285   86.5244
# 4746   90.2815   86.7606
# 4747   90.6770   86.9978
# 4748   90.9105   87.1828
# 4749   90.9010   87.2684
# 4750   91.0535   87.4328
# 4751   91.1230   87.5598

# %%
new_data.set_index('date' , inplace=True)

# %%
new_data
# Out:
#                open     high      low    close     volume  Name  close_10  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL       NaN
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL       NaN
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL       NaN
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL       NaN
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL       NaN
# ...             ...      ...      ...      ...        ...   ...       ...
# 2018-02-01  94.7900  96.0700  93.5813  94.2600   47227882  MSFT    92.765
# 2018-02-02  93.6400  93.9700  91.5000  91.7800   47867753  MSFT    92.943
# 2018-02-05  90.5600  93.2400  88.0000  88.0000   51031465  MSFT    92.582
# 2018-02-06  86.8900  91.4750  85.2500  91.3300   67998564  MSFT    92.525
# 2018-02-07  90.4900  91.7700  89.2000  89.6100   41107592  MSFT    92.304
#
#             close_20  close_50
# date
# 2013-02-08       NaN       NaN
# 2013-02-11       NaN       NaN
# 2013-02-12       NaN       NaN
# 2013-02-13       NaN       NaN
# 2013-02-14       NaN       NaN
# ...              ...       ...
# 2018-02-01   90.6770   86.9978
# 2018-02-02   90.9105   87.1828
# 2018-02-05   90.9010   87.2684
# 2018-02-06   91.0535   87.4328
# 2018-02-07   91.1230   87.5598
#
# [4752 rows x 9 columns]

# %%
new_data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'Name', 'close_10',
#        'close_20', 'close_50'],
#       dtype='object')

# %%
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index)
    filter1 = new_data['Name']==company
    df = new_data[filter1]
    df[['close_10','close_20', 'close_50']].plot(ax=plt.gca())
    plt.title(company)

# %% [markdown]
# ## 4.. analyse Closing price change in apple stock !
# ##### Daily Stock Return Formula
#     To calculate how much you gained or lost per day for a stock, subtract the opening price from the closing price. Then, multiply the result by the number of shares you own in the company.

# %%
company_list
# Out:
# ['D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\AAPL_data.csv',
#  'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\AMZN_data.csv',
#  'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\GOOG_data.csv',
#  'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\MSFT_data.csv']

# %%
apple = pd.read_csv(r'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\AAPL_data.csv')

# %%
apple.head(4)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL

# %%
apple['close']
# Out:
# 0        67.8542
# 1        68.5614
# 2        66.8428
# 3        66.7156
# 4        66.6556
#           ...
# 1254    167.7800
# 1255    160.5000
# 1256    156.4900
# 1257    163.0300
# 1258    159.5400
# Name: close, Length: 1259, dtype: float64

# %%
apple.head(4)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL

# %%
apple['Daily return(in %)'] = apple['close'].pct_change() * 100

### pct_change() returns : Percentage change between the current and a prior element.

# %%
apple.head(4)
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#    Daily return(in %)
# 0                 NaN
# 1            1.042235
# 2           -2.506658
# 3           -0.190297

# %%
import plotly.express as px

# %%
px.line(apple , x="date" , y="Daily return(in %)") ## Plotting Line-plot of "date" vs "Daily return(in %)"..

# %% [markdown]
# ## 5.. Performing resampling analysis of closing price ..

# %% [markdown]
#     Before doing resampling,first u have to make your date feature 'row-index' so that u can resample data on various basis :
#
#     a..yearly('Y')  ,
#     b..quarterly('Q')   ,
#     c..monthly('M') ,
#     d..weekly basis ('W'),
#     e..Daily_basis('D')
#     f..minutes ('3T') ,
#     g..30 second bins('30S')   ,
#     h..resample('17min')

# %%
apple.dtypes
# Out:
# date                   object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                  int64
# Name                   object
# Daily return(in %)    float64
# dtype: object

# %%
apple['date'] =pd.to_datetime(apple['date'])

# %%
apple.dtypes
# Out:
# date                  datetime64[ns]
# open                         float64
# high                         float64
# low                          float64
# close                        float64
# volume                         int64
# Name                          object
# Daily return(in %)           float64
# dtype: object

# %%
apple.head(4)
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#    Daily return(in %)
# 0                 NaN
# 1            1.042235
# 2           -2.506658
# 3           -0.190297

# %%
apple.set_index('date' , inplace=True)

# %%
apple.head(4)
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#             Daily return(in %)
# date
# 2013-02-08                 NaN
# 2013-02-11            1.042235
# 2013-02-12           -2.506658
# 2013-02-13           -0.190297

# %%
apple['close'].resample('M').mean() ## resample data on monthly basis ..
# Out:
# date
# 2013-02-28     65.306264
# 2013-03-31     63.120110
# 2013-04-30     59.966432
# 2013-05-31     63.778927
# 2013-06-30     60.791120
#                  ...
# 2017-10-31    157.817273
# 2017-11-30    172.406190
# 2017-12-31    171.891500
# 2018-01-31    174.005238
# 2018-02-28    161.468000
# Freq: ME, Name: close, Length: 61, dtype: float64

# %%
apple['close'].resample('M').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple['close'].resample('Y').mean() ## resample data on Yearly basis ..
# Out:
# date
# 2013-12-31     67.237839
# 2014-12-31     92.264531
# 2015-12-31    120.039861
# 2016-12-31    104.604008
# 2017-12-31    150.585080
# 2018-12-31    171.594231
# Freq: YE-DEC, Name: close, dtype: float64

# %%
apple['close'].resample('Y').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple['close'].resample('Q').mean() ## resample data on Quarterly basis ..
# Out:
# date
# 2013-03-31     64.020291
# 2013-06-30     61.534692
# 2013-09-30     66.320670
# 2013-12-31     75.567478
# 2014-03-31     76.086293
# 2014-06-30     85.117475
# 2014-09-30     98.163311
# 2014-12-31    108.821016
# 2015-03-31    120.776721
# 2015-06-30    127.937937
# 2015-09-30    117.303438
# 2015-12-31    114.299297
# 2016-03-31     99.655082
# 2016-06-30     99.401250
# 2016-09-30    105.866094
# 2016-12-31    113.399048
# 2017-03-31    131.712500
# 2017-06-30    147.875397
# 2017-09-30    155.304603
# 2017-12-31    167.148254
# 2018-03-31    171.594231
# Freq: QE-DEC, Name: close, dtype: float64

# %%
apple['close'].resample('Q').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## 6.. Whether closing prices of these tech companies (Amazon,Apple,Google,Microsoft) are correlated or not !

# %%
company_list
# Out:
# ['D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\AAPL_data.csv',
#  'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\AMZN_data.csv',
#  'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\GOOG_data.csv',
#  'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\MSFT_data.csv']

# %%
company_list[0]
# Out:
# 'D:\\\\S&P_resources\\\\individual_stocks_5yr\\\\AAPL_data.csv'

# %%
app = pd.read_csv(company_list[0])
amzn = pd.read_csv(company_list[1])
google = pd.read_csv(company_list[2])
msft = pd.read_csv(company_list[3])

# %%
closing_price = pd.DataFrame()

# %%
closing_price['apple_close'] = app['close']
closing_price['amzn_close'] = amzn['close']
closing_price['goog_close'] = google['close']
closing_price['msft_close'] = msft['close']

# %%
closing_price
# Out:
#       apple_close  amzn_close  goog_close  msft_close
# 0         67.8542      261.95      558.46       27.55
# 1         68.5614      257.21      559.99       27.86
# 2         66.8428      258.70      556.97       27.88
# 3         66.7156      269.47      567.16       28.03
# 4         66.6556      269.24      567.00       28.04
# ...           ...         ...         ...         ...
# 1254     167.7800     1390.00         NaN       94.26
# 1255     160.5000     1429.95         NaN       91.78
# 1256     156.4900     1390.00         NaN       88.00
# 1257     163.0300     1442.84         NaN       91.33
# 1258     159.5400     1416.78         NaN       89.61
#
# [1259 rows x 4 columns]

# %%
'''
    Pair-plot is all about , we can considering some pairs & 
    we are trying to plot scatterplot of it..
    
    Unique plots : 4c2 = 6 unique plots
    
    Total plots : 15 ( 6 unique + 6 mirror images of these 
    unique one + 3 diagonal plots(histogram))

'''


# Dis-advantages: 
## Can't be used when number of features are high.
## Cannot visualize higher dimensional patterns in 3-D and 4-D. 
## Only possible to view 2D patterns.



# NOTE: the diagnol elements are (histogram) for each feature.
# Out:
# '\n    Pair-plot is all about , we can considering some pairs & \n    we are trying to plot scatterplot of it..\n    \n    Unique plots : 4c2 = 6 unique plots\n    \n    Total plots : 15 ( 6 unique + 6 mirror images of these \n    unique one + 3 diagonal plots(histogram))\n\n'

# %%
sns.pairplot(closing_price)

# %%
closing_price.corr()
# Out:
#              apple_close  amzn_close  goog_close  msft_close
# apple_close     1.000000    0.819078    0.640522    0.899689
# amzn_close      0.819078    1.000000    0.888456    0.955977
# goog_close      0.640522    0.888456    1.000000    0.907011
# msft_close      0.899689    0.955977    0.907011    1.000000

# %% [markdown]
# #### co-relation plot for stock prices

# %%
sns.heatmap(closing_price.corr() , annot=True)
# Out:
# <Axes: >

# %%
'''

Conclusions : 
Closing price of Google and Microsoft are well correlated
& Closing price of Amazon and Microsoft have a co-relation of 0.96


'''
# Out:
# '\n\nConclusions : \nClosing price of Google and Microsoft are well correlated\n& Closing price of Amazon and Microsoft have a co-relation of 0.96\n\n\n'

# %% [markdown]
# ## 7.. analyse Whether Daily change in Closing price of stocks or Daily Returns in Stock are co-related or not !

# %%
closing_price
# Out:
#       apple_close  amzn_close  goog_close  msft_close
# 0         67.8542      261.95      558.46       27.55
# 1         68.5614      257.21      559.99       27.86
# 2         66.8428      258.70      556.97       27.88
# 3         66.7156      269.47      567.16       28.03
# 4         66.6556      269.24      567.00       28.04
# ...           ...         ...         ...         ...
# 1254     167.7800     1390.00         NaN       94.26
# 1255     160.5000     1429.95         NaN       91.78
# 1256     156.4900     1390.00         NaN       88.00
# 1257     163.0300     1442.84         NaN       91.33
# 1258     159.5400     1416.78         NaN       89.61
#
# [1259 rows x 4 columns]

# %%
closing_price['apple_close']
# Out:
# 0        67.8542
# 1        68.5614
# 2        66.8428
# 3        66.7156
# 4        66.6556
#           ...
# 1254    167.7800
# 1255    160.5000
# 1256    156.4900
# 1257    163.0300
# 1258    159.5400
# Name: apple_close, Length: 1259, dtype: float64

# %%
closing_price['apple_close'].shift(1)
# Out:
# 0            NaN
# 1        67.8542
# 2        68.5614
# 3        66.8428
# 4        66.7156
#           ...
# 1254    167.4300
# 1255    167.7800
# 1256    160.5000
# 1257    156.4900
# 1258    163.0300
# Name: apple_close, Length: 1259, dtype: float64

# %%
(closing_price['apple_close'] - closing_price['apple_close'].shift(1))/closing_price['apple_close'].shift(1) * 100
# Out:
# 0            NaN
# 1       1.042235
# 2      -2.506658
# 3      -0.190297
# 4      -0.089934
#           ...
# 1254    0.209043
# 1255   -4.339015
# 1256   -2.498442
# 1257    4.179181
# 1258   -2.140710
# Name: apple_close, Length: 1259, dtype: float64

# %%
for col in closing_price.columns:
    closing_price[col + '_pct_change'] = (closing_price[col] - closing_price[col].shift(1))/closing_price[col].shift(1) * 100

# %%
closing_price
# Out:
#       apple_close  amzn_close  goog_close  msft_close  apple_close_pct_change  \
# 0         67.8542      261.95      558.46       27.55                     NaN
# 1         68.5614      257.21      559.99       27.86                1.042235
# 2         66.8428      258.70      556.97       27.88               -2.506658
# 3         66.7156      269.47      567.16       28.03               -0.190297
# 4         66.6556      269.24      567.00       28.04               -0.089934
# ...           ...         ...         ...         ...                     ...
# 1254     167.7800     1390.00         NaN       94.26                0.209043
# 1255     160.5000     1429.95         NaN       91.78               -4.339015
# 1256     156.4900     1390.00         NaN       88.00               -2.498442
# 1257     163.0300     1442.84         NaN       91.33                4.179181
# 1258     159.5400     1416.78         NaN       89.61               -2.140710
#
#       amzn_close_pct_change  goog_close_pct_change  msft_close_pct_change
# 0                       NaN                    NaN                    NaN
# 1                 -1.809506               0.273968               1.125227
# 2                  0.579293              -0.539295               0.071788
# 3                  4.163123               1.829542               0.538020
# 4                 -0.085353              -0.028211               0.035676
# ...                     ...                    ...                    ...
# 1254              -4.196734                    NaN              -0.789391
# 1255               2.874101                    NaN              -2.631021
# 1256              -2.793804                    NaN              -4.118544
# 1257               3.801439                    NaN               3.784091
# 1258              -1.806160                    NaN              -1.883280
#
# [1259 rows x 8 columns]

# %%
closing_price.columns
# Out:
# Index(['apple_close', 'amzn_close', 'goog_close', 'msft_close',
#        'apple_close_pct_change', 'amzn_close_pct_change',
#        'goog_close_pct_change', 'msft_close_pct_change'],
#       dtype='object')

# %%
clsing_p = closing_price[['apple_close_pct_change', 'amzn_close_pct_change',
       'goog_close_pct_change', 'msft_close_pct_change']]

# %%
clsing_p
# Out:
#       apple_close_pct_change  amzn_close_pct_change  goog_close_pct_change  \
# 0                        NaN                    NaN                    NaN
# 1                   1.042235              -1.809506               0.273968
# 2                  -2.506658               0.579293              -0.539295
# 3                  -0.190297               4.163123               1.829542
# 4                  -0.089934              -0.085353              -0.028211
# ...                      ...                    ...                    ...
# 1254                0.209043              -4.196734                    NaN
# 1255               -4.339015               2.874101                    NaN
# 1256               -2.498442              -2.793804                    NaN
# 1257                4.179181               3.801439                    NaN
# 1258               -2.140710              -1.806160                    NaN
#
#       msft_close_pct_change
# 0                       NaN
# 1                  1.125227
# 2                  0.071788
# 3                  0.538020
# 4                  0.035676
# ...                     ...
# 1254              -0.789391
# 1255              -2.631021
# 1256              -4.118544
# 1257               3.784091
# 1258              -1.883280
#
# [1259 rows x 4 columns]

# %%
### since we have used Pairplot already , lets use extension of Pairplot , ie Pairgrid :

# %%
'''
Pairplot : we have histogram on diagonals & scatterplot/kde/
            any_other_plot which tells dist.. on rest of the plot 


Pairgrid : Once we create grid , we can set plot as per our need : 

ie , if we have 4 features , it creates total 16 graphs/plots or matrices of 4*4



    There would be various possibilities for type of plots in our Pairgrid which we can set as per our need :

    a) all plots can be scatterplot
    b) on diagonal , we have histogram & rest will be scatterplot
    c) on diagonal , we have histogram & rest will be kdeplot 
    c) on diagonal , we have histogram & below diagonal will be kdeplot
            & upper diagonal will be scatterplot 

Note :: kdeplot for 2 features also known as contour plots which returns density
but kdeplot returns distribution if we are performing univariate analysis else it will show density ..

'''
# Out:
# '\nPairplot : we have histogram on diagonals & scatterplot/kde/\n            any_other_plot which tells dist.. on rest of the plot \n\n\nPairgrid : Once we create grid , we can set plot as per our need : \n\nie , if we have 4 features , it creates total 16 graphs/plots or matrices of 4*4\n\n\n\n    There would be various possibilities for type of plots in our Pairgrid which we can set as per our need :\n\n    a) all plots can be scatterplot\n    b) on diagonal , we have histogram & rest will be scatterplot\n    c) on diagonal , we have histogram & rest will be kdeplot \n    c) on diagonal , we have histogram & below diagonal will be kdeplot\n            & upper diagonal will be scatterplot \n\nNote :: kdeplot for 2 features also known as contour plots which returns density\nbut kdeplot returns distribution if we are performing univariate analysis else it will show density ..\n\n'

# %%
g = sns.PairGrid(data= clsing_p)
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)

# %%
'''

Conclusion :
While Comparing 'AAPL_close_pct_change' to 'AMZN_close_pct_change'  , it shows a linear relationship upto some extent..


'''
# Out:
# "\n\nConclusion :\nWhile Comparing 'AAPL_close_pct_change' to 'AMZN_close_pct_change'  , it shows a linear relationship upto some extent..\n\n\n"

# %%
clsing_p.corr()
# Out:
#                         apple_close_pct_change  amzn_close_pct_change  \
# apple_close_pct_change                1.000000               0.287659
# amzn_close_pct_change                 0.287659               1.000000
# goog_close_pct_change                 0.036202               0.027698
# msft_close_pct_change                 0.366598               0.402678
#
#                         goog_close_pct_change  msft_close_pct_change
# apple_close_pct_change               0.036202               0.366598
# amzn_close_pct_change                0.027698               0.402678
# goog_close_pct_change                1.000000               0.038939
# msft_close_pct_change                0.038939               1.000000
